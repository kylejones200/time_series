# %%
# !pip install pandas geopandas keplergl matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.4/18.4 MB 38.5 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached pyproj-3.7.0-cp312-cp312-macosx_14_0_arm64.whl.metadata (31 kB)
# ...
#   Using cached shapely-2.0.6-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.0 kB)
# ...
#   Using cached ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached jupyter_packaging-0.12.3-py3-none-any.whl.metadata (7.7 kB)
# ...
#   Using cached widgetsnbextension-4.0.13-py3-none-any.whl.metadata (1.6 kB)
# ...
#   Using cached jupyterlab_widgets-3.0.13-py3-none-any.whl.metadata (4.1 kB)
# ...
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# ...
#   Using cached uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# ...

# %%
latitude,longitude,location,date,temperature,army_size
54.35,23.55,Kowno,1812-06-24,,422000
55.75,37.62,Moscow,1812-09-14,,100000
54.41,30.44,Smolensk,1812-11-14,-20,24000
54.35,23.55,Kowno,1812-12-13,-30,10000
