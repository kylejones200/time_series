# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os
import time
import random

def download_reports():
    # Create a session
    session = requests.Session()

    # Set up headers
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        'Accept-Language': 'en-US,en;q=0.5',
        'Referer': 'https://www.fire.ca.gov/',
    }

    # Step 1: Fetch the updates page
    updates_url = 'https://www.fire.ca.gov/incidents/2025/1/7/eaton-fire/updates'
    print(f"Fetching URL: {updates_url}")
    response = session.get(updates_url, headers=headers)
    response.raise_for_status()

    # Step 2: Parse the updates page to find report links
    soup = BeautifulSoup(response.text, 'html.parser')
    print("Page title:", soup.title.string if soup.title else "No title found")

    report_links = soup.select('a[href*="/incidents/"]')
    print(f"Found {len(report_links)} potential report links")

    if len(report_links) == 0:
        print("HTML content:")
        print(soup.prettify()[:1000])  # Print first 1000 characters of HTML
        return

    # Create a directory to store HTML files
    os.makedirs('eaton_html_files', exist_ok=True)

    # Step 3: Download each report
    for i, link in enumerate(report_links):
        report_url = 'https://www.fire.ca.gov' + link['href'] if link['href'].startswith('/') else link['href']
        print(f"Downloading report from: {report_url}")

        try:
            report_response = session.get(report_url, headers=headers)
            report_response.raise_for_status()

            with open(f'eaton_html_files/report_{i}.html', 'w', encoding='utf-8') as f:
                f.write(report_response.text)

            print(f"Successfully downloaded report {i+1}")
        except requests.HTTPError as e:
            print(f"Failed to download report {i+1}: {str(e)}")

        time.sleep(random.uniform(2, 5))  # Random delay between 2 and 5 seconds

    print(f"Attempted to download {len(report_links)} reports.")

# Run the function
download_reports()
# Out:
# Fetching URL: https://www.fire.ca.gov/incidents/2025/1/7/eaton-fire/updates
# Page title: Eaton Fire Status Update Reports | CAL FIRE
# Found 101 potential report links
# Downloading report from: https://www.fire.ca.gov/incidents/2025/1/7/eaton-fire/updates/edc23958-8118-4a09-b9b1-1d95a9557d5a
# Successfully downloaded report 1
# Downloading report from: https://www.fire.ca.gov/incidents/2025/1/7/eaton-fire/updates/1c002ecd-47c5-44eb-8f2a-e54f37545a19
# Successfully downloaded report 2
# Downloading report from: https://www.fire.ca.gov/incidents/2025/1/7/eaton-fire/updates/4042ddbe-c07a-4bca-86f0-21da6759cf76
# Successfully downloaded report 3
# Downloading report from: https://www.fire.ca.gov/incidents/2025/1/7/eaton-fire/updates/2a081542-343a-4524-a745-390d79542ca1
# Successfully downloaded report 4
# Downloading report from: https://www.fire.ca.gov/incidents/2025/1/7/eaton-fire/updates/04d43971-e5f3-482c-875c-e7549acea423
# Successfully downloaded report 5
# Downloading report from: https://www.fire.ca.gov/incidents/2025/1/7/eaton-fire/updates/d1c7f356-b60f-4595-bf10-793df09f0127
# Successfully downloaded report 6
# Downloading report from: https://www.fire.ca.gov/incidents/2025/1/7/eaton-fire/updates/4baedaa7-d506-40ef-a86b-b54771ca13d2
# Successfully downloaded report 7
# Downloading report from: https://www.fire.ca.gov/incidents/2025/1/7/eaton-fire/updates/505faec3-af71-49b1-b41c-35755cd604f4
# Successfully downloaded report 8
# Downloading report from: https://www.fire.ca.gov/incidents/2025/1/7/eaton-fire/updates/8514dd88-299f-480b-8b09-5481a656c11e
# Successfully downloaded report 9
# Downloading report from: https://www.fire.ca.gov/incidents/2025/1/7/eaton-fire/updates/2ddcc7fe-a153-4ae5-a3aa-bdfec2ef77db
# Successfully downloaded report 10
# Downloading report from: https://www.fire.ca.gov/incidents/2025/1/7/eaton-fire/updates/c422b1c8-a963-4c86-b496-fa0b68bde707
# Successfully downloaded report 11
# Downloading report from: https://www.fire.ca.gov/incidents/2025/1/7/eaton-fire/updates/ebd8c327-7837-4b65-af9f-00d155d0b7a2
# Successfully downloaded report 12
# Downloading report from: https://www.fire.ca.gov/incidents/2025/1/7/eaton-fire/updates/8cdc3fa3-6e4b-40a7-b743-bab4887638c8
# Successfully downloaded report 13
# Downloading report from: https://www.fire.ca.gov/incidents/2025/1/7/eaton-fire/updates/bfacb7d2-5e2c-4dfe-83df-b40ab24fd1ac
# Successfully downloaded report 14
# Downloading report from: https://www.fire.ca.gov/incidents/2025/1/7/eaton-fire/updates/81f28ba7-ad54-4145-aae6-48a515c14269
# Successfully downloaded report 15
# Downloading report from: https://www.fire.ca.gov/incidents/2025/1/7/eaton-fire/updates/2154c479-e04c-4dde-83cd-83ab13f5e6f2
# Successfully downloaded report 16
# Downloading report from: https://www.fire.ca.gov/incidents/2025/1/7/eaton-fire/updates/069711e1-15d4-46aa-a3ea-65b1d1a9817f
# Successfully downloaded report 17
# Downloading report from: https://www.fire.ca.gov/incidents/2025/1/7/eaton-fire/updates/e03e8cc4-45db-4485-aefc-d8a382da3793
# Successfully downloaded report 18
# Downloading report from: https://www.fire.ca.gov/incidents/2025/1/7/eaton-fire/updates/35b2302a-d8af-4362-a05c-c86a325a1e34
# Successfully downloaded report 19
# Downloading report from: https://www.fire.ca.gov/incidents/2025/1/7/eaton-fire/updates/9ece4970-faad-4f86-974e-427695338dbd
# Successfully downloaded report 20
# Downloading report from: https://www.fire.ca.gov/incidents/2025/1/7/eaton-fire/updates/ec82ed4e-1073-44e5-8054-3333f125b634
# Successfully downloaded report 21
# Downloading report from: https://www.fire.ca.gov/incidents/2025/1/7/eaton-fire/updates/51c0925e-116b-4c68-ae16-4bd9cf786041
# Successfully downloaded report 22
# Downloading report from: https://www.fire.ca.gov/incidents/2025/1/7/eaton-fire/updates
# Downloading report from: https://www.fire.ca.gov/incidents/2025/1/7/eaton-fire/updates/35f4cb4c-4023-4484-a7b2-d0c2a40a5880
# Successfully downloaded report 99
# Downloading report from: https://www.fire.ca.gov/incidents/2025/1/7/eaton-fire/updates/33a317a9-3830-4d55-a6a6-a1889a124079
# Successfully downloaded report 100
# Downloading report from: https://www.fire.ca.gov/incidents/2024
# Successfully downloaded report 101
# Attempted to download 101 reports.

# %% [markdown]
# This code works to pull the update report.

# %%
"""
Works to parse the data and make the dataframe
"""

import os
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime

fire = "eaton"

def extract_data_from_html(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        soup = BeautifulSoup(file.read(), 'html.parser')

    data = {}

    # Extract date and time
    main_content = soup.find('main', id='main-content')
    if main_content:
        date_time_dl = main_content.find('dl', class_='mb-0')
        if date_time_dl:
            date_dd = date_time_dl.find('dd', string=lambda text: text and '/' in text)
            time_dd = date_time_dl.find_all('dd')[-1]  # Assume the last dd is the time
            if date_dd:
                data['Date'] = date_dd.text.strip()
            if time_dd:
                data['Time'] = time_dd.text.strip()

    # Extract incident facts
    incident_facts = soup.find('div', class_='border border-danger-dark mt-4')
    if incident_facts:
        dl_tags = incident_facts.find_all('dl', class_='row')
        for dl in dl_tags:
            dt_tags = dl.find_all('dt')
            dd_tags = dl.find_all('dd')
            for dt, dd in zip(dt_tags, dd_tags):
                key = dt.text.strip()
                value = dd.text.strip()
                data[key] = value

    # Extract assigned resources
    assigned_resources = soup.find('h2', string='Assigned Resources')
    if assigned_resources:
        resources_div = assigned_resources.find_parent('div', class_='border border-danger-dark mt-4')
        if resources_div:
            dl_tags = resources_div.find_all('dl', class_='row')
            for dl in dl_tags:
                dt_tags = dl.find_all('dt')
                dd_tags = dl.find_all('dd')
                for dt, dd in zip(dt_tags, dd_tags):
                    key = dt.text.strip()
                    value = dd.text.strip()
                    data[key] = value

    return data


def process_all_html_files(directory):
    all_data = []
    for filename in os.listdir(directory):
        if filename.endswith('.html'):
            file_path = os.path.join(directory, filename)
            data = extract_data_from_html(file_path)
            all_data.append(data)

    return pd.DataFrame(all_data)

# Process all HTML files in the 'html_files' directory
df = process_all_html_files(f'{fire}_html_files')

# Convert Date and Time columns to datetime if they exist
if 'Date' in df.columns and 'Time' in df.columns:
    df['DateTime'] = pd.to_datetime(df['Date'] + ' ' + df['Time'], format='%m/%d/%Y %I:%M %p', errors='coerce')
    df = df.sort_values('DateTime', ascending=False)

# Display the DataFrame
print(df)
df['Size'] = df['Size'].replace(',', '', regex=True).astype(float).astype('Int64')


# Optionally, save the DataFrame to a CSV file
df.to_csv(f'{fire}_fire_incident_data.csv', index=False)
# Out:
#           Date     Time        Name Start Date/Time Incident Status  \
# 99  01/11/2025  3:34 PM  Eaton Fire      2025-01-07          Active
# 6   01/11/2025  3:12 PM  Eaton Fire      2025-01-07          Active
# 33  01/11/2025  3:02 PM  Eaton Fire      2025-01-07          Active
# 86  01/11/2025  1:21 PM  Eaton Fire      2025-01-07          Active
# 71  01/11/2025  1:14 PM  Eaton Fire      2025-01-07          Active
# ..         ...      ...         ...             ...             ...
# 18  01/07/2025  7:39 PM  Eaton Fire      2025-01-07          Active
# 58  01/07/2025  7:27 PM  Eaton Fire      2025-01-07          Active
# 32  01/07/2025  7:25 PM  Eaton Fire      2025-01-07          Active
# 37  01/07/2025  6:49 PM  Close Fire      2025-01-07          Active
# 41         NaN      NaN         NaN             NaN             NaN
#
#                                              Location      Type  \
# 99  Near Altadena Drive and Midwick Drive, Altaden...  Wildfire
# 6   Near Altadena Drive and Midwick Drive, Altaden...  Wildfire
# 33  Near Altadena Drive and Midwick Drive, Altaden...  Wildfire
# 86  Near Altadena Drive and Midwick Drive, Altaden...  Wildfire
# 71  Near Altadena Drive and Midwick Drive, Altaden...  Wildfire
# ..                                                ...       ...
# 18  Near Altadena Drive and Midwick Drive, Altaden...  Wildfire
# 58  Near Altadena Drive and Midwick Drive, Altaden...  Wildfire
# 32  Near Altadena Drive and Midwick Drive, Altaden...  Wildfire
# 37  Near Altadena Drive and Midwick Drive, Altaden...  Wildfire
# 41                                                NaN       NaN
#
#                   Cause     Counties  \
# 99  Under Investigation  Los Angeles
# 6   Under Investigation  Los Angeles
# 33  Under Investigation  Los Angeles
# 86  Under Investigation  Los Angeles
# 71  Under Investigation  Los Angeles
# ..                  ...          ...
# 18  Under Investigation  Los Angeles
# 58  Under Investigation  Los Angeles
# 32  Under Investigation  Los Angeles
# 37  Under Investigation  Los Angeles
# 41                  NaN          NaN
#
#                                   Administration Unit  ... Civilian Injuries  \
# 99  Los Angeles County Fire Department, Pasadena F...  ...
# 6   Los Angeles County Fire Department, Pasadena F...  ...
# 33  Los Angeles County Fire Department, Pasadena F...  ...
# 86  Los Angeles County Fire Department, Pasadena F...  ...
# 71  Los Angeles County Fire Department, Pasadena F...  ...
# ..                                                ...  ...               ...
# 18  Los Angeles County Fire Department, Pasadena F...  ...
# 58  Los Angeles County Fire Department, Pasadena F...  ...
# 32  Los Angeles County Fire Department, Pasadena F...  ...
# 37                                                     ...
# 41                                                NaN  ...               NaN
#
#    Firefighter Injuries Civilian Fatalities Firefighter Fatalities Engines  \
# 99                    5                   5                            391
# 6                     5                   5                            391
# 33                    5                   5                            391
# 86                    5                   5                            391
# 71                    5                   5                            391
# ..                  ...                 ...                    ...     ...
# 18                                                                     NaN
# 58                                                                     NaN
# 32                                                                     NaN
# 37                                                                     NaN
# 41                  NaN                 NaN                    NaN     NaN
#
#    Water Tenders Dozers Hand Crews Total Personnel            DateTime
# 99           112     32         38            2832 2025-01-11 15:34:00
# 6            112     32         38            2832 2025-01-11 15:12:00
# 33           112     32         38            2832 2025-01-11 15:02:00
# 86           112     32         38            2832 2025-01-11 13:21:00
# 71           112     32         38            2832 2025-01-11 13:14:00
# ..           ...    ...        ...             ...                 ...
# 18           NaN    NaN        NaN             NaN 2025-01-07 19:39:00
# 58           NaN    NaN        NaN             NaN 2025-01-07 19:27:00
# 32           NaN    NaN        NaN             NaN 2025-01-07 19:25:00
# 37           NaN    NaN        NaN             NaN 2025-01-07 18:49:00
# 41           NaN    NaN        NaN             NaN                 NaT
#
# [101 rows x 26 columns]

# %%
import pandas as pd
import os
import glob

def merge_csv_files(directory):
    # List to store individual dataframes
    dataframes = []

    # Use glob to get all CSV files in the directory
    csv_files = glob.glob(os.path.join(directory, "*.csv"))

    # Check if any CSV files were found
    if not csv_files:
        print(f"Warning: No CSV files found in directory: {directory}")
        return pd.DataFrame()  # Return an empty DataFrame if no files found

    for file_path in csv_files:
        # Read the CSV file
        df = pd.read_csv(file_path)

        # Add a column with the file name
        df['Source File'] = os.path.basename(file_path)

        # Append to the list of dataframes
        dataframes.append(df)

    # Merge all dataframes
    merged_df = pd.concat(dataframes, ignore_index=True, sort=False)

    return merged_df

# Replace with the actual directory containing your CSV files
# directory = 'path/to/your/csv/files/'
directory = './'  # Use the current directory, for example

# Merge the CSV files
result = merge_csv_files(directory)



# Save the merged dataframe to a new CSV file
result.to_csv('merged_output.csv', index=False)
print("Merged CSV has been saved as 'merged_output.csv'")

# Print the number of files merged
print(f"Number of CSV files merged: {len(result['Source File'].unique())}")
# Out:
# Merged CSV has been saved as 'merged_output.csv'
# Number of CSV files merged: 2
